# %% [markdown]
# <a href="https://colab.research.google.com/github/fguedes-datascience/portfolio/blob/main/An%C3%A1lise_de_Campanha_de_Marketing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Projeto Análise de Campanha de Marketing**

# %% [markdown]
#  Projeto de marketing realizado em uma das etapas do curso da Data Science Academy. Nele, foi realizado uma análise de uma campanha de dados, utilizando quatro visões diferentes:
# Visão do cliente: Analisando a distribuição dos clientes nos diferentes segmentos e categorias dos dados.
# Visão comportamento: Explorando as relações entre as variáveis para compreender os padrões de consumo dos clientes.
# Visão Campanhas: Avaliando a eficácia das campanhas de Marketing realizadas por meio de gráficos e indicadores.
# Visão dos Pontos de Venda: Apresentando os gastos totais e por categoria dos pontos de venda e suas respectivas participações no faturamento.

# %% [markdown]
# ![Visao cliente.png](data:image/png;base64,...)

# %% [markdown]
# ![Visao comportamento.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# ![visao campanha.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# ![visao pontos de vendas.JPG](data:image/jpeg;base64,...)
